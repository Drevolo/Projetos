# %%
#Automação para Baixar NF de Saida na Sefaz GO

import pyautogui
import time
import PySimpleGUI as sg

sg.theme('Topanga')

pyautogui.PAUSE = 0.5

pi = '01042024'
pf = '30042024'

#Abrir o Site
time.sleep(2)
pyautogui.hotkey('win','1')
time.sleep(3)
pyautogui.write('https://goias.gov.br/economia/')
pyautogui.press('Enter')
time.sleep(3)
pyautogui.click(643,340)
pyautogui.scroll(-200)
pyautogui.click(533,561)
time.sleep(2)
pyautogui.click(646,388)
pyautogui.scroll(-200)
pyautogui.click(966,651)

#Pegar os Arquivos
o1 = sg.popup_get_text('Coloque o Certificado. Quando terminar escreva (ok)')
if o1 == 'ok':
    pyautogui.hotkey('Alt','Tab')
    pyautogui.click(688,643)
    time.sleep(3)
    pyautogui.click(224,278)
    pyautogui.write(pi)
    pyautogui.press('Tab')
    pyautogui.write(pf)
    pyautogui.press('Tab')
    pyautogui.press('Tab')
    pyautogui.press('right')
    pyautogui.click(707,710)

    pyautogui.hotkey('Alt','Tab')
    o2 = sg.popup_get_text('(ok)')
    if o2 == 'ok':
        pyautogui.hotkey('Alt','Tab')
        verifica = pyautogui.pixel(505,110)
        if verifica != (242, 222, 222):
        
            pyautogui.click(724,701)
            pyautogui.click(929,325)

            o3 = sg.popup_get_text('Coloque a Pasta. Quando terminar escreva (ok)')
            if o3 == 'ok':
                pyautogui.hotkey('Alt','Tab')
                pyautogui.click(769,557)
                pyautogui.write('55')
                pyautogui.press('Enter')

                #Continuidade
                pyautogui.click(596,697)
                time.sleep(2)
                pyautogui.click(221,279)
                pyautogui.write(pi)
                pyautogui.press('Tab')
                pyautogui.write(pf)
                pyautogui.press('Tab')
                pyautogui.press('Tab')
                pyautogui.press(['right', 'right', 'right'])
                pyautogui.click(707,710)
                
                pyautogui.hotkey('Alt','Tab')
                o4 = sg.popup_get_text('(ok)')
                if o4 == 'ok':
                    pyautogui.hotkey('Alt','Tab')
                    verifica = pyautogui.pixel(505,110)
                    if verifica != (242, 222, 222):
                        
                        pyautogui.click(724,701)
                        pyautogui.click(929,325)

                        qwe = sg.popup_get_text('Coloque a Pasta. Quando terminar escreva (ok)')
                        if qwe == 'ok':
                            pyautogui.hotkey('Alt','Tab')
                            pyautogui.write('65')
                            pyautogui.press('Enter')


        else:
            #Continuidade
            pyautogui.click(202,327)
            pyautogui.write(pi)
            pyautogui.press('Tab')
            pyautogui.write(pf)
            pyautogui.press('Tab')
            pyautogui.press('Tab')
            pyautogui.press(['right', 'right', 'right'])
            pyautogui.scroll(-200)
            pyautogui.click(709,700)

            pyautogui.hotkey('Alt','Tab')
            o5 = sg.popup_get_text('(ok)')
            if o5 == 'ok':
                pyautogui.hotkey('Alt','Tab')
                verifica = pyautogui.pixel(505,110)
                if verifica != (242, 222, 222):
                    
                    pyautogui.click(724,701)
                    pyautogui.click(929,325)

                    oll = sg.popup_get_text('Coloque a Pasta. Quando terminar escreva (ok)')
                    if oll == 'ok':
                        pyautogui.hotkey('Alt','Tab')
                        pyautogui.click(624,561)
                        pyautogui.write('65')
                        pyautogui.press('Enter')
                else:
                    pass

time.sleep(2)
pyautogui.hotkey('Alt','F4')
sg.popup('Fim')
print('Fim')
# Out:
# Fim
